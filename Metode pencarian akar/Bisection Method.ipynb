# %%
# tanpa tolerance 

import math

def bisection(f, a, b):
   

    fa = f(a)
    fb = f(b)
    
    if fa*fb >0:
        print("f(a) and f(b) must have different signs.")
        return None
    
    for i in range(100):
         
        c = (a+b)/2
        fc = f(c)
        
        if fc == 0:
            break
        
        if fa*fc > 0:
            a, fa = c, fc
            
        if fb*fc > 0:
            b,fb = c,fc
    
    return c

func = lambda x : x**2 -x -1
a = 1
b = 5
x = bisection(func, a, b)
print("Solution Found: {}".format(x))

func2 = lambda x : x**2 - math.exp(-x) -1
x2 = bisection(func2, -1, 5)
print("Solution of 2nd equation :{}".format(x2))
# Out:
# Solution Found: 1.618033988749895
# Solution of 2nd equation :1.1477576321447436

# %%
# menggunakan tolerance

import math

def bisection(f, a, b, tol = 1e-10):
    
    fa = f(a)
    if abs(fa) < tol:
        return a
    
    fb = f(b)
    if abs(fb) < tol:
        return b
    
    if fa*fb > 0:
        print("f(a) and f(b) must have different signs.")
        return None
    
    for i in range(100):
        c = (a+b)/2
        fc = f(c)
    
        if fc == 0:
            break
        
        if fa*fc > 0:
            a, fa = c, fc
        
        if fb*fc > 0:
            b, fb = c, fc
    
    return c

func = lambda x : x**2-  x - 1

            
            
        

def ()

# %%
import math

def bisection(f, a, b, tol = 1e-15):
    
    fa = f(a)
    if abs(fa) < tol:
        return a
    
    fb = f(b)
    if abs(fb) < tol:
        return b
        
    if fa*fb > 0 :
        print( " f(a) and f (b) must have different signs.")
        return none
    
    for i in range(100):
        
        c = (a + b)/2
        fc = f(c)
        
        if abs(fc) <tol:
            break
        
        if fa*fc > 0:
            a, fa = c, fc
        
        if fb*fc > 0 :
            b,fb = c, fc
        
    return c

func = lambda x : x*x*x + x**2 - 3*x - 2
a = 1
b = 7
x = bisection(func, a, b)
print("Akar solusi: {}".format(x))

#func2 = lambda x : x**2 - math.exp(-x) -1
#x2 = bisection(func2, -1, 5)
#print("Solution Found: {}".format(x))
# Out:
# Akar solusi: 1.618033988749895

# %%
import math

def bisection(f, a, b, tol = 1e-15):
    
    fa = f(a)
    if abs(fa) < tol:
        return a
    
    fb = f(b)
    if abs(fb) < tol:
        return b
        
    if fa*fb > 0 :
        print( " f(a) and f (b) must have different signs.")
        return none
    
    for i in range(100):
        
        c = (a + b)/2
        fc = f(c)
        
        if abs(fc) <tol:
            break
        
        if fa*fc > 0:
            a, fa = c, fc
        
        if fb*fc > 0 :
            b,fb = c, fc
        
    return c

func = lambda x : x**2 - x -1
a = 1
b = 5
x = bisection(func, a, b)
print("Akar solusi: {}".format(x))

#func2 = lambda x : x**2 - math.exp(-x) -1
#x2 = bisection(func2, -1, 5)
#print("Solution Found: {}".format(x))
# Out:
# Akar solusi: 1.618033988749895

# %%
import math

def bisection(f, a, b, tol = 1e-15):
    
    fa = f(a)
    if abs(fa) < tol:
        return a
    
    fb = f(b)
    if abs(fb) < tol:
        return b
        
    if fa*fb > 0 :
        print( " f(a) and f (b) must have different signs.")
        return none
    
    for i in range(100):
        
        c = (a + b)/2
        fc = f(c)
        
        if abs(fc) <tol:
            break
        
        if fa*fc > 0:
            a, fa = c, fc
        
        if fb*fc > 0 :
            b,fb = c, fc
        
    return c

func = lambda x : x*x*x + x**2 - 3*x - 2
a = 1
b = 7
x = bisection(func, a, b)
print("Akar solusi: {}".format(x))

#func2 = lambda x : x**2 - math.exp(-x) -1
#x2 = bisection(func2, -1, 5)
#print("Solution Found: {}".format(x))
